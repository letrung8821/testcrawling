# %%
from urllib.request import urlopen
import re

# %%
def download_page(url):
    return urlopen(url).read().decode('utf-8')
def extract_links(page):
    link_regex = re.compile('<a[^>]+href=["\'](.*?)["\']',
    re.IGNORECASE)
    return link_regex.findall(page)
if __name__ == '__main__':
    target_url = 'http://www.apress.com/'
    apress = download_page(target_url)
    links = extract_links(apress)
    for link in links:
        print(link)
# Out:
# http://www.apress.com
# /
# https://www.apress.com/is-changing
# https://www.apress.com/searching
# #menu
# https://www.apress.com/account
# https://www.apress.com/searching
# #
# /gp/apple
# /gp/big-data
# /gp/business
# /gp/databases
# /gp/enterprise-software
# /gp/game-development
# /gp/graphics
# /gp/hardware-maker
# /gp/java
# /gp/machine-learning
# /gp/microsoft
# /gp/mobile
# /gp/networking
# /gp/open-source
# /gp/programming
# /gp/python
# /gp/security
# /gp/web-development
# /gp/services/publishing-partners
# #
# /gp/about
# /gp/services/academics
# /gp/shop/affiliate/springer-nature
# /gp/services/book-reviewers
# /gp/services/corporate-sales
# https://www.apress.com/customer-support
# /gp/services/events
# /gp/services/rights-permission
# /gp/services/source-code
# /gp/services/errata
# /gp/services/tech-review
# /gp/apress-open
# /gp/blog
# /gp/write-for-us
# #
# /gp/shop
# /gp/services/booksellers
# /gp/services/bulk-sales
# /gp/services/corporate-sales
# /gp/services/librarians
# https://www.apress.com/searching
# https://link.springer.com/search?package=41786&amp;facet-content-type=%22Book%22
# https://www.apress.com/gp/is-changing
# /gp/apple
# /gp/big-data
# /gp/business
# /gp/databases
# /gp/enterprise-software
# /gp/game-development
# /gp/graphics
# /gp/hardware-maker
# /gp/java
# /gp/machine-learning
# /gp/microsoft
# /gp/mobile
# /gp/networking
# /gp/open-source
# /gp/programming
# /gp/python
# /gp/security
# /gp/web-development
# /gp/book/9781484259306
# /gp/book/9781484254394
# /gp/book/9781484257562
# /gp/book/9781484213339
# /gp/book/9781484243664
# /gp/book/9781484244500
# /gp/book/9781484259276
# /gp/book/9781484259979
# /gp/book/9781484258835
# /gp/book/9781484239872
# https://twitter.com/Apress? ref_src=twsrc%5Etfw
# https://link.springer.com/book/10.1007/978-1-4842-5772-2
# https://link.springer.com/book/10.1007/978-1-4842-5952-8
# /gp/blog
# /gp/blog/all-blog-posts/authors-code-iuliana-cosmina/20141682
# /gp/blog/all-blog-posts/authors-code-iuliana-cosmina/20141682
# /gp/blog/all-blog-posts/are-video-games-hackable/19665066
# /gp/blog/all-blog-posts/are-video-games-hackable/19665066
# /gp/services/source-code
# /gp/write-for-us
# https://twitter.com/sean_ong
# /gp/apple
# /gp
# /gp/big-data
# /gp/business
# /gp/databases
# /gp/enterprise-software
# /gp/game-development
# /gp/graphics
# /gp/hardware-maker
# /gp/java
# /gp/machine-learning
# /gp/microsoft
# /gp/mobile
# /gp/networking
# /gp/open-source
# /gp/programming
# /gp/services/publishing-partners
# /gp/python
# /gp/security
# /gp/web-development
# /gp/services/publishing-partners
# /gp/about
# /gp/services/academics
# /gp/shop/affiliate/springer-nature
# /gp/services/book-reviewers
# /gp/services/corporate-sales
# https://www.apress.com/customer-support
# /gp/services/events
# /gp/services/rights-permission
# /gp/services/source-code
# /gp/services/errata
# /gp/services/tech-review
# /gp/write-for-us
# /gp/write-for-us/submit-a-proposal
# /gp/write-for-us/publishing-process
# /gp/write-for-us/author-services
# /gp/about
# /gp/blog
# /gp/services/events
# https://support.apress.com/en/support/home
# /gp/services/publishing-partners
# /gp/services/contact-us
# /gp/about/team
# /
# /gp/legal/cookie-policy
# /gp/legal/apress-terms-and-conditions/10875332
# /gp/legal
# https://www.springernature.com/ccpa
# https://www.instagram.com/apresshq/
# https://www.youtube.com/channel/UCToEnUFnPa1GjN_ovvomCEw
# https://www.linkedin.com/company/apress/
# https://www.facebook.com/ApressMedia/
# https://twitter.com/apress
# http://enable-javascript.com/

# %%
from urllib.request import urlopen, urljoin
import re
def download_page(url):
    return urlopen(url).read().decode('utf-8')

def extract_links(page):
    link_regex = re.compile('<a[^>]+href=["\'](.*?)["\']',
    re.IGNORECASE)
    return link_regex.findall(page)
if __name__ == '__main__':
    target_url = 'http://www.apress.com/'
    apress = download_page(target_url)
    links = extract_links(apress)
    for link in links:
        print(urljoin(target_url, link))
# Out:
# http://www.apress.com
# http://www.apress.com/
# https://www.apress.com/is-changing
# https://www.apress.com/searching
# http://www.apress.com/#menu
# https://www.apress.com/account
# https://www.apress.com/searching
# http://www.apress.com/
# http://www.apress.com/gp/apple
# http://www.apress.com/gp/big-data
# http://www.apress.com/gp/business
# http://www.apress.com/gp/databases
# http://www.apress.com/gp/enterprise-software
# http://www.apress.com/gp/game-development
# http://www.apress.com/gp/graphics
# http://www.apress.com/gp/hardware-maker
# http://www.apress.com/gp/java
# http://www.apress.com/gp/machine-learning
# http://www.apress.com/gp/microsoft
# http://www.apress.com/gp/mobile
# http://www.apress.com/gp/networking
# http://www.apress.com/gp/open-source
# http://www.apress.com/gp/programming
# http://www.apress.com/gp/python
# http://www.apress.com/gp/security
# http://www.apress.com/gp/web-development
# http://www.apress.com/gp/services/publishing-partners
# http://www.apress.com/
# http://www.apress.com/gp/about
# http://www.apress.com/gp/services/academics
# http://www.apress.com/gp/shop/affiliate/springer-nature
# http://www.apress.com/gp/services/book-reviewers
# http://www.apress.com/gp/services/corporate-sales
# https://www.apress.com/customer-support
# http://www.apress.com/gp/services/events
# http://www.apress.com/gp/services/rights-permission
# http://www.apress.com/gp/services/source-code
# http://www.apress.com/gp/services/errata
# http://www.apress.com/gp/services/tech-review
# http://www.apress.com/gp/apress-open
# http://www.apress.com/gp/blog
# http://www.apress.com/gp/write-for-us
# http://www.apress.com/
# http://www.apress.com/gp/shop
# http://www.apress.com/gp/services/booksellers
# http://www.apress.com/gp/services/bulk-sales
# http://www.apress.com/gp/services/corporate-sales
# http://www.apress.com/gp/services/librarians
# https://www.apress.com/searching
# https://link.springer.com/search?package=41786&amp;facet-content-type=%22Book%22
# https://www.apress.com/gp/is-changing
# http://www.apress.com/gp/apple
# http://www.apress.com/gp/big-data
# http://www.apress.com/gp/business
# http://www.apress.com/gp/databases
# http://www.apress.com/gp/enterprise-software
# http://www.apress.com/gp/game-development
# http://www.apress.com/gp/graphics
# http://www.apress.com/gp/hardware-maker
# http://www.apress.com/gp/java
# http://www.apress.com/gp/machine-learning
# http://www.apress.com/gp/microsoft
# http://www.apress.com/gp/mobile
# http://www.apress.com/gp/networking
# http://www.apress.com/gp/open-source
# http://www.apress.com/gp/programming
# http://www.apress.com/gp/python
# http://www.apress.com/gp/security
# http://www.apress.com/gp/web-development
# http://www.apress.com/gp/book/9781484259306
# http://www.apress.com/gp/book/9781484254394
# http://www.apress.com/gp/book/9781484257562
# http://www.apress.com/gp/book/9781484213339
# http://www.apress.com/gp/book/9781484243664
# http://www.apress.com/gp/book/9781484244500
# http://www.apress.com/gp/book/9781484259276
# http://www.apress.com/gp/book/9781484259979
# http://www.apress.com/gp/book/9781484258835
# http://www.apress.com/gp/book/9781484239872
# https://twitter.com/Apress? ref_src=twsrc%5Etfw
# https://link.springer.com/book/10.1007/978-1-4842-5772-2
# https://link.springer.com/book/10.1007/978-1-4842-5952-8
# http://www.apress.com/gp/blog
# http://www.apress.com/gp/blog/all-blog-posts/authors-code-iuliana-cosmina/20141682
# http://www.apress.com/gp/blog/all-blog-posts/authors-code-iuliana-cosmina/20141682
# http://www.apress.com/gp/blog/all-blog-posts/are-video-games-hackable/19665066
# http://www.apress.com/gp/blog/all-blog-posts/are-video-games-hackable/19665066
# http://www.apress.com/gp/services/source-code
# http://www.apress.com/gp/write-for-us
# https://twitter.com/sean_ong
# http://www.apress.com/gp/apple
# http://www.apress.com/gp
# http://www.apress.com/gp/big-data
# http://www.apress.com/gp/business
# http://www.apress.com/gp/databases
# http://www.apress.com/gp/enterprise-software
# http://www.apress.com/gp/game-development
# http://www.apress.com/gp/graphics
# http://www.apress.com/gp/hardware-maker
# http://www.apress.com/gp/java
# http://www.apress.com/gp/machine-learning
# http://www.apress.com/gp/microsoft
# http://www.apress.com/gp/mobile
# http://www.apress.com/gp/networking
# http://www.apress.com/gp/open-source
# http://www.apress.com/gp/programming
# http://www.apress.com/gp/services/publishing-partners
# http://www.apress.com/gp/python
# http://www.apress.com/gp/security
# http://www.apress.com/gp/web-development
# http://www.apress.com/gp/services/publishing-partners
# http://www.apress.com/gp/about
# http://www.apress.com/gp/services/academics
# http://www.apress.com/gp/shop/affiliate/springer-nature
# http://www.apress.com/gp/services/book-reviewers
# http://www.apress.com/gp/services/corporate-sales
# https://www.apress.com/customer-support
# http://www.apress.com/gp/services/events
# http://www.apress.com/gp/services/rights-permission
# http://www.apress.com/gp/services/source-code
# http://www.apress.com/gp/services/errata
# http://www.apress.com/gp/services/tech-review
# http://www.apress.com/gp/write-for-us
# http://www.apress.com/gp/write-for-us/submit-a-proposal
# http://www.apress.com/gp/write-for-us/publishing-process
# http://www.apress.com/gp/write-for-us/author-services
# http://www.apress.com/gp/about
# http://www.apress.com/gp/blog
# http://www.apress.com/gp/services/events
# https://support.apress.com/en/support/home
# http://www.apress.com/gp/services/publishing-partners
# http://www.apress.com/gp/services/contact-us
# http://www.apress.com/gp/about/team
# http://www.apress.com/
# http://www.apress.com/gp/legal/cookie-policy
# http://www.apress.com/gp/legal/apress-terms-and-conditions/10875332
# http://www.apress.com/gp/legal
# https://www.springernature.com/ccpa
# https://twitter.com/apress
# https://www.facebook.com/ApressMedia/
# https://www.linkedin.com/company/apress/
# https://www.youtube.com/channel/UCToEnUFnPa1GjN_ovvomCEw
# https://www.instagram.com/apresshq/
# http://enable-javascript.com/
