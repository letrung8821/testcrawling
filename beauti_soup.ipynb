# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (from requests) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (from requests) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (from requests) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (from requests) (3.3)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\levan\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\levan\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\Users\levan\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
r = requests.get("https://tinhte.vn")

# %%
soup = bs(r.content)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="vi">
#  <head>
#   <base href="/"/>
#   <script id="page-configs" type="application/json">
#    {&#x22;expiredAt&#x22;:1646855285261,&#x22;ttl&#x22;:60,&#x22;home_logo&#x22;:&#x22;123.png&#x22;,&#x22;nav_color&#x22;:&#x22;#3c5894&#x22;,&#x22;top_video&#x22;:{&#x22;title&#x22;:&#x22;Livestream b&#xE0;n v&#x1EC1; Mac Studio, chip Apple M1 Ultra&#x22;,&#x22;id&#x22;:&#x22;&#x22;,&#x22;video_id&#x22;:&#x22;&#x22;,&#x22;thread_id&#x22;:&#x22;&#x22;},&#x22;main_promotion&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;mobile_img_url&#x22;:&#x22;&#x22;,&#x22;desktop_img_url&#x22;:&#x22;&#x22;,&#x22;__app_action&#x22;:{&#x22;type&#x22;:&#x22;community&#x22;,&#x22;tag_text&#x22;:&#x22;tet19&#x22;},&#x22;app_action&#x22;:{&#x22;type&#x22;:&#x22;threadview&#x22;,&#x22;thread_id&#x22;:&#x22;2910954&#x22;,&#x22;content_id&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;}},&#x22;thread_view_promotion&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;mobile_img_url&#x22;:&#x22;&#x22;,&#x22;desktop_img_url&#x22;:&#x22;&#x22;,&#x22;__app_action&#x22;:{&#x22;type&#x22;:&#x22;community&#x22;,&#x22;tag_text&#x22;:&#x22;tet19&#x22;},&#x22;app_action&#x22;:{&#x22;type&#x22;:&#x22;webview&#x22;,&#x22;thread_id&#x22;:&#x22;&#x22;,&#x22;content_id&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;}},&#x22;app_promotion&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;mobile_img_url&#x22;:&#x22;&#x22;,&#x22;desktop_img_url&#x22;:&#x22;&#x22;,&#x22;__app_action&#x22;:{&#x22;type&#x22;:&#x22;community&#x22;,&#x22;tag_text&#x22;:&#x22;tet19&#x22;},&#x22;app_action&#x22;:{&#x22;type&#x22;:&#x22;webview&#x22;,&#x22;thread_id&#x22;:&#x22;2910954&#x22;,&#x22;content_id&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;}},&#x22;top_promotion&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;mobile_img_url&#x22;:&#x22;&#x22;,&#x22;desktop_img_url&#x22;:&#x22;&#x22;,&#x22;app_action&#x22;:{&#x22;type&#x22;:&#x22;threadview&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;content_id&#x22;:&#x22;&#x22;}},&#x22;hero_bottom_promotion&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;mobile_img_url&#x22;:&#x22;&#x22;,&#x22;desktop_img_url&#x22;:&#x22;&#x22;,&#x22;app_action&#x22;:{&#x22;type&#x22;:&#x22;webview&#x22;,&#x22;url&#x22;:&#x22;&#x22;,&#x22;content_id&#x22;:&#x22;&#x22;}},&#x22;top_promotion_xe&#x22;:{&#x22;title&#x22;:&#x22;&#x22;,&#x22;url&#x22;:&#x22;&#x22
_url&#x22;:&#x22;https://tinhte.vn/styles/default/Tinhte/Reactions/angry.png&#x22;,&#x22;svg_image_url&#x22;:&#x22;https://tinhte.vn/styles/default/Tinhte/Reactions/angry.svg&#x22;}}]}
#   </script>
#   <script src="/static/js/tinhteTheme-v8.11.5.js">
#   </script>
#   <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
#   <title>
#    Cộng đồng Khoa học &amp; Công nghệ | Tinh tế
#   </title>
#   <script type="application/ld+json">
#    {"@id":"https://tinhte.vn/#Organization","@context":"http://schema.org","@type":"Organization","name":"Tinh tế","url":"https://tinhte.vn/","logo":{"@type":"ImageObject","url":"https://tinhte.vn/static/images/tinhte_logo_length_black.png","width":289,"height":67},"contactPoint":[{"@type":"ContactPoint","telephone":"02862713156","contactType":"customer service","areaServed":"VN","availableLanguage":["EN","VN"]}],"sameAs":["https://www.youtube.com/user/tinhtevideo","https://www.facebook.com/tinhte","https://vi.wikipedia.org/wiki/Tinhte.vn"]}
#   </script>
#   <script type="application/ld+json">
#    {"@type":"WebPage","@context":"https://schema.org","@id":"https://tinhte.vn/#WebPage","url":"https://tinhte.vn/","inLanguage":["EN","VN"],"name":"Tinh tế","publisher":{"@id":"https://tinhte.vn/#Organization","@type":"Organization","name":"Tinhte.vn","logo":{"@type":"ImageObject","url":"https://tinhte.vn/static/images/tinhte_logo_length_black.png","width":289,"height":67}},"description":"Cộng đồng công nghệ, thủ thuật, tư vấn về điện thoại, máy tính, camera, đồ điện gia dụng và âm thanh, khoa học kĩ thuật. Nơi giải đáp thắc mắc, hỏi đáp công nghệ."}
#   </script>
#   <script type="application/ld+json">
#    {"@type":"WebSite","@context":"https://schema.org","url":"https://tinhte.vn/","name":"Tinh tế"}
#   </script>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link data-href="https://fonts.googleapis.com/css2?family=Inter:wght@400;500;600;700;800&amp;display=swap" data-optimized-fonts="true" rel="stylesheet"/>
#   <link href="/static/fonts/FontAwesome/all.css" rel="stylesheet"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.5.2/animate.min.css" rel="stylesheet"/>
#   <link href="/static/images/icons/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.11.0/jquery.min.js">
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="công nghệ, khoa học, kĩ thuật, mẹo vặt, cộng đồng, thảo luận, hỏi đáp, sửa lỗi, máy tính, sự cố, camera, lỗi điện thoại, lỗi máy tính" name="keywords"/>
#   <meta content="Tinh tế" name="author"/>
#   <meta content="Cổng ty Cổ phần Mạng xã hội Tinh tế" name="publisher"/>
#   <meta content="Cổng ty Cổ phần Mạng xã hội Tinh tế" name="copyright"/>
#   <meta content="122102927812763" property="fb:pages"/>
#   <meta content="Cộng đồng công nghệ, thủ thuật, tư vấn về điện thoại, máy tính, camera, đồ điện gia dụng và âm thanh, khoa học kĩ thuật. Nơi giải đáp thắc mắc, hỏi đáp công nghệ." name="description"/>
#   <meta content="Tinhte.vn" property="og:site_name"/>
#   <meta content="https://photo2.tinhte.vn/data/attachment-files/2020/07/5075745_OG_newHome_2020_2.jpg" property="og:image"/>
#   <meta content="article" property="og:type"/>
#   <meta content="https://tinhte.vn/" property="og:url"/>
#   <meta content="Cộng đồng Khoa học &amp; Công nghệ | Tinh tế" property="og:title"/>
#   <meta content="Cộng đồng công nghệ, thủ thuật, tư vấn về điện thoại, máy tính, camera, đồ điện gia dụng và âm thanh, khoa học kĩ thuật. Nơi giải đáp thắc mắc, hỏi đáp công nghệ." property="og:description"/>
#   <meta content="summary" property="twitter:card"/>
#   <meta content="Cộng đồng Khoa học &amp; Công nghệ | Tinh tế" property="twitter:title"/>
#   <meta content="Cộng đồng công nghệ, thủ thuật, tư vấn về điện thoại, máy tính, camera, đồ điện gia dụng và âm thanh, khoa học kĩ thuật. Nơi giải đáp thắc mắc, hỏi đáp công nghệ." property="twitter:description"/>
#   <meta content="https://photo2.tinhte.vn/data/attachment-files/2020/07/5075745_OG_newHome_2020_2.jpg" property="twitter:image"/>
#   <meta content="https://tinhte.vn/" property="twitter:url"/>
#   <meta content="145923738846814" property="fb:app_id"/>
#   <meta content="#0E1620" name="msapplication-TileColor"/>
#   <link href="https://tinhte.vn/rss/" rel="alternate" title="RSS của Tinhte.vn" type="application/rss+xml"/>
#   <link href="/static/images/icons/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/>
#   <link href="https://tinhte.vn" rel="canonical"/>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#                   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#                   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#                   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#                   ga('create', 'UA-2120640-1', 'auto');
#                   ga('send', 'pageview');
#   </script>
#   <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#   </script>
#   <script>
#    (adsbygoogle = window.adsbygoogle || []).push({
#                       google_ad_client: "ca-pub-4328742155432872",
#                       enable_page_level_ads: true
#                     });
#   </script>
#   <script async="" src="https://static.amcdn.vn/tka/cdn.js">
#   </script>
#   <script>
#    var arfAsync = arfAsync || [];
#   </script>
#   <script async="" id="arf-core-js" src="//media1.admicro.vn/cms/Arf.min.js">
#   </script>
#   <script>
#    function ccadnet_fb(id) {
#                     var s = document.createElement('script');
#                     s.src = 'https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js';
#                     var ins = document.createElement('ins');
#                     ins.className='adsbygoogle';
#                     ins.style='display:inline-block;width:300px;height:250px'
#                     ins.dataset.adClient = 'ca-pub-4328742155432872';
#                     var ccad = document.getElementById(id);
#                     var ccadParent = ccad.parentNode;
#                     ccadParent.insertBefore(ins, ccad);
#                     ccadParent.removeChild(ccad);
#                     (adsbygoogle = window.adsbygoogle || []).push({});
#                     document.head.appendChild(s);
#                   }
#   </script>
#   <script>
#    !function(f,b,e,v,n,t,s)
#       {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#       n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#       if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#       n.queue=[];t=b.createElement(e);t.async=!0;
#       t.src=v;s=b.getElementsByTagName(e)[0];
#       s.parentNode.insertBefore(t,s)}(window, document,'script',
#       'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '559511104461231');
#       fbq('track', 'PageView');
#   </script>
#   <script>
#    fbq('track', 'ViewContent', {
#         value: 1,
#         currency: 'VND',
#       });
#   </script>
#   <script>
#    window.fbAsyncInit = function() {
#         FB.init({
#           appId            : '145923738846814',
#           autoLogAppEvents : true,
#           xfbml            : true,
#           version          : 'v12.0'
#         });
#       };
#
#       (function(d, s, id){
#         var js, fjs = d.getElementsByTagName(s)[0];
#         if (d.getElementById(id)) {return;}
#         js = d.createElement(s); js.id = id;
#         js.src = "https://connect.facebook.net/en_US/sdk.js";
#         fjs.parentNode.insertBefore(js, fjs);
#       }(document, 'script', 'facebook-jssdk'));
#   </script>
#   <script src="https://www.gstatic.com/firebasejs/7.5.2/firebase-app.js" type="text/javascript">
#   </script>
#   <script src="https://www.gstatic.com/firebasejs/7.5.2/firebase-analytics.js" type="text/javascript">
#   </script>
#   <script>
#    var firebaseConfig = {
#         apiKey: "AIzaSyDWAPFMaWXFbERvNRUpiMdEvvVEo4_4gtc",
#         authDomain: "tinhte-apps.firebaseapp.com",
#         databaseURL: "https://tinhte-apps.firebaseio.com",
#         projectId: "tinhte-apps",
#         storageBucket: "tinhte-apps.appspot.com",
#         messagingSenderId: "460325099291",
#         appId: "1:460325099291:web:dc1cfc774ab8b65a4ae5be",
#         measurementId: "G-L2J9ZH0B0E"
#       };
#       firebase.initializeApp(firebaseConfig);
#       firebase.analytics();
#   </script>
#   <meta content="48" name="next-head-count"/>
#   <link as="style" href="/_next/static/css
display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.search-icon.jsx-3389971726:hover{cursor:pointer;}.search-textbox.jsx-3389971726{font-size:14px;padding-right:57px;display:block;-webkit-transition:width 0.3s ease;transition:width 0.3s ease;width:0px;padding:0;}.search-textbox.jsx-3389971726:focus{outline:none;}.open.jsx-3389971726 .search-textbox.jsx-3389971726{width:180px;padding-right:5px;}
#   </style>
#   <style id="__jsx-3599443646">
#    header.jsx-3599443646{z-index:98;position:relative;}.header-wrapper.jsx-3599443646{padding-top:20px;padding-bottom:20px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}.header-wrapper.jsx-3599443646 .left.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;padding-right:0;width:auto;}.header-wrapper.jsx-3599443646 .middle.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}@media (max-width:1199px){.header-wrapper.jsx-3599443646 .middle.jsx-3599443646{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}.header-wrapper.jsx-3599443646 .right.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;width:auto;}@media (max-width:1199px){.header-wrapper.jsx-3599443646 .right.jsx-3599443646{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}}.header-wrapper.jsx-3599443646 .menu-wrapper.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.header-wrapper.jsx-3599443646 .desktop-menu.jsx-3599443646{display:none;}@media (min-width:768px){.header-wrapper.jsx-3599443646 .desktop-menu.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}.logo.jsx-3599443646{margin-right:15px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}@media (max-width:375px){.logo.jsx-3599443646{margin-right:10px;}}@media (min-width:768px){.logo.jsx-3599443646{margin-right:26px;}}.logo.jsx-3599443646 .tinhte-logo.jsx-3599443646{width:40px;vertical-align:middle;display:inline-block;}.logo.jsx-3599443646 .tinhte-logo.jsx-3599443646 svg{display:block;}.logo.jsx-3599443646 .tinhte-text.jsx-3599443646{font-size:24px;font-weight:600;margin-left:12px;vertical-align:middle;display:inline-block;}@media (max-width:575px){.logo.jsx-3599443646 .tinhte-text.jsx-3599443646{display:none;}}.search.jsx-3599443646{display:none;position:relative;}@media (min-width:768px){.search.jsx-3599443646{display:block;}}.menu-icon.jsx-3599443646{font-size:15px;font-weight:600;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;}.menu-icon.jsx-3599443646>*.jsx-3599443646{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.menu-icon.jsx-3599443646 .icon.jsx-3599443646{width:40px;height:40px;border-radius:50%;background-color:var(--header-menu-button);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.menu-icon.jsx-3599443646 .icon.jsx-3599443646:hover{cursor:pointer;}.menu-icon.jsx-3599443646 .icon-label.jsx-3599443646{margin-left:12px;display:none;}@media (min-width:992px){.menu-icon.jsx-3599443646 .icon-label.jsx-3599443646{display:block;}}.delimiter.jsx-3599443646{margin:0 12px;height:32px;width:1px;display:inline-block;background-color:var(--header-menu-button);}.black-header.jsx-3599443646{box-shadow:none;display:-webkit-box;display ...
#   </style>
#   <style id="__jsx-3662144972">
#    span.jsx-3662144972{width:24px;height:24px;position:relative;display:inline-block;}span.jsx-3662144972:before,span.jsx-3662144972:after{content:"";border-radius:100%;position:absolute;margin:auto;top:0;right:0;bottom:0;left:0;display:inline-block;}.hightlight.jsx-3662144972:before{width:100%;height:100%;background:var(--primary-color);opacity:0.2;-webkit-animation:zoom-jsx-3662144972 1s ease-out infinite;animation:zoom-jsx-3662144972 1s ease-out infinite;}.hightlight.jsx-3662144972:after{width:10px;height:10px;background:var(--primary-color);-webkit-animation:zoom-jsx-3662144972 1s ease-in 0.05s infinite;animation:zoom-jsx-3662144972 1s ease-in 0.05s infinite;}.red-highlight.jsx-3662144972:before,.red-highlight.jsx-3662144972:after{background:var(--color-alert-badge);}.blue-highlight.jsx-3662144972:before,.blue-highlight.jsx-3662144972:after{background:var(--primary-color);}@-webkit-keyframes zoom-jsx-3662144972{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}50%{-webkit-transform:scale(0.75);-ms-transform:scale(0.75);transform:scale(0.75);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}@keyframes zoom-jsx-3662144972{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}50%{-webkit-transform:scale(0.75);-ms-transform:scale(0.75);transform:scale(0.75);}100%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);}}
#   </style>
#   <style id="__jsx-3470779898">
#    .preview-view-container.jsx-3470779898{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-radius:8px;position:relative;text-align:center;overflow:hidden;width:var(--fact-card-width);height:var(--fact-card-height);background-image:var(--gradient-3-button);}.preview-view-img.jsx-3470779898{position:absolute;top:-20px;left:-20px;width:calc(100% + 40px);height:calc(100% + 40px);-webkit-filter:blur(10px);-webkit-filter:blur(10px);filter:blur(10px);-webkit-filter:blur(10px);background-position:center;background-repeat:no-repeat;background-size:cover;}.preview-view-container.no-background-color.jsx-3470779898{background-image:none;}.avatar.jsx-3470779898{position:relative;width:50px;height:50px;border-radius:50%;border:2px solid var(--inverse-text);background-size:contain;background-repeat:no-repeat;background-position:center center;}.avatar-plus.jsx-3470779898{color:var(--inverse-text);font-size:20px;line-height:17px;width:18px;height:18px;border-radius:50%;bottom:-2px;right:-2px;position:absolute;background-color:var(--primary-color);}.create-fact.jsx-3470779898{color:var(--inverse-text);font-size:13px;font-weight:600;margin-top:4px;z-index:2;}
#   </style>
#   <style id="__jsx-659482973">
#    .thread-editor.jsx-659482973{position:relative;}.thread-editor.jsx-659482973 .blue-switch.jsx-659482973{color:var(--text-on-primary-color);font-size:14px;font-weight:600;line-height:17px;text-transform:capitalize;padding:10px 15px;margin:0 auto;width:100%;border-radius:5px;background-color:var(--primary-color);display:block;}.thread-editor.jsx-659482973 .blue-switch.header-mode.jsx-659482973{padding:10px 24px;border-radius:80px;}.thread-editor-modal{height:100%;max-height:600px;max-width:650px;overflow-x:hidden;margin:0 auto;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);position:relative;box-shadow:0 5px 20px 0 var(--box-shadow);background:var(--new-thread-body);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}.thread-editor-modal:focus{outline:none;}.reset-btn.jsx-659482973:hover{background-color:var(--hover-background);}.reset-btn.jsx-659482973 svg{width:18px;height:18px;}.reset-btn.jsx-659482973 svg path{fill:var(--dark-icon);}.top-area.jsx-659482973{font-size:16px;font-weight:700;line-height:1;padding:16px 12px;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 56px;-ms-flex:0 0 56px;flex:0 0 56px;border-bottom:1px solid var(--border-light);background-color:var(--new-thread-header);}@media (min-width:576px){.top-area.jsx-659482973{padding:16px 24px;}}.middle-area.jsx-659482973{padding:0 12px;overflow-y:auto;-webkit-flex:1 1 0;-ms-flex:1 1 0;flex:1 1 0;}@media (min-width:576px){.middle-area.jsx-659482973{padding:0 24px;}}.middle-area.jsx-659482973 .textbox-area.jsx-659482973{padding:16px 0 6px;}.middle-area.jsx-659482973 .additional-tools.jsx-659482973{border-radius:60px;padding:8px 8px 8px 15px;margin:0 0 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;border:1px solid var(--border-light);}.bottom-area.jsx-659482973{padding:8px 12px;background-color:var(--new-thread-footer);-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex:0 0 82px;-ms-flex:0 0 82px;flex:0 0 82px;}@media (min-width:576px){.bottom-area.jsx-659482973{padding:16px 24px;}}.link-input.jsx-659482973{margin-top:12px;margin-bottom:12px;font-size:16px;padding:6px 0;width:100%;border-radius:4px;}.link-input.jsx-659482973:focus{outline:none;}.thread-editor-textarea{width:100%;height:auto;outline:none;resize:none;max-height:300px;overflow-y:auto;margin:6px 0 15px;padding:6px 0;border-radius:4px;}@media (max-width:365px){.thread-editor-textarea{max-height:110px;}}.textbox__tools.jsx-659482973{display:block;}@media (min-width:576px){.textbox__tools.jsx-659482973{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}}.profile__info.jsx-659482973{margin-bottom:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.profile__info.jsx-659482973 .profile__info__photo.jsx-659482973{margin-right:8px;border-radius:50%;overflow:hidden;background-color:var(--avatar-background-dark);}.profile__info.jsx-659482973 .profile__info__name.jsx-659482973{font-weig ...
#   </style>
#   <style id="__jsx-131847778">
#    .image-loader.jsx-131847778{overflow:hidden;position:relative;display:block;}.image-loader.jsx-131847778 .spacer.jsx-131847778{display:block;padding-bottom:100%;background-color:var(--header-menu-button);}.image-loader.jsx-131847778>img.jsx-131847778{width:100%;height:100%;top:0;bottom:0;left:0;right:0;position:absolute;object-fit:cover;}
#   </style>
#   <style id="__jsx-401967567">
#    .avatar.jsx-401967567{width:32px;height:32px;margin-right:8px;border-radius:100%;border:1px solid;border-color:var(--blue-border);background-color:var(--grey-background);display:block;}.avatar.jsx-401967567>img.jsx-401967567{display:block;}@media (max-width:575px){.avatar.jsx-401967567:not(.no-scale){width:28px !important;height:28px !important;}}
#   </style>
#   <style id="__jsx-3067764999">
#    .preview-view-container.jsx-3067764999{text-align:center;width:var(--fact-card-width);height:var(--fact-card-height);border-radius:8px;overflow:hidden;position:relative;background-image:var(--gradient-3-button);}.preview-view-img.jsx-3067764999{object-fit:cover;width:var(--fact-card-width);height:var(--fact-card-height);border-radius:8px;-webkit-transform:scale(1.2);-ms-transform:scale(1.2);transform:scale(1.2);-webkit-transition:all 0.4s ease;transition:all 0.4s ease;}.preview-view-container.jsx-3067764999:hover>.preview-view-img.jsx-3067764999{-webkit-transition:all 0.4s ease;transition:all 0.4s ease;-webkit-transform:scale(1.4);-ms-transform:scale(1.4);transform:scale(1.4);}.preview-view-author-avatar.jsx-3067764999{top:8px;left:9px;position:absolute;}.preview-view-author.jsx-3067764999{color:var(--inverse-text);font-weight:500;font-size:13px;bottom:8px;left:9px;position:absolute;max-width:90px;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}.preview-mask.jsx-3067764999{width:100%;top:0;bottom:0;left:0;right:0;position:absolute;background-image:var(--mask-background);opacity:0.8;}.video-fact-icon.jsx-3067764999{top:6px;right:6px;position:absolute;z-index:1;}
#   </style>
#   <style id="__jsx-4083475239">
#    .main.jsx-4083475239{position:relative;}.section-heading.jsx-4083475239{margin-bottom:0;}.facts-container.jsx-4083475239{margin-top:24px;overflow-x:auto;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.lookback.jsx-4083475239{margin-bottom:8px;margin-left:4px;margin-right:4px;}.item.jsx-4083475239{padding:0 6px 8px;}.item.jsx-4083475239:first-child{padding-left:0;}.item.jsx-4083475239:last-child{padding-right:0;}.header.jsx-4083475239{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.follow.jsx-4083475239{color:var(--primary-color);font-size:14px;font-weight:600;}.load-more-container.jsx-4083475239{border-radius:8px;width:var(--fact-card-width);height:var(--fact-card-height);display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}.load-more-icon.jsx-4083475239{font-size:16px;}.load-more.jsx-4083475239{font-size:14px;margin:10px 0 0 0;}@media (max-width:767px){.load-more-container.jsx-4083475239{width:80px;height:150px;}}
#   </style>
#   <style id="__jsx-2790954478">
#    .page-layout.jsx-2790954478{background-color:var(--page-background);}.page-layout.dark-bg.jsx-2790954478{background:var(--light-grey-background);}.page-layout.white-bg.jsx-2790954478{background:var(--light-background);}.additional-padding.jsx-2790954478{padding-top:8px;}@media (min-width:992px){.additional-padding.jsx-2790954478{padding-top:16px;}}
#   </style>
#   <style id="__jsx-3808261869">
#    .thumb-wrapper.jsx-3808261869{position:relative;}.thumb.jsx-3808261869{background-position:center;background-size:cover;background-repeat:no-repeat;display:block;height:100%;margin:0;padding:0;width:100%;background-color:var(--button-light);border:1px solid var(--border-thread-thumbnail);}.thumb.no-border.jsx-3808261869{border:0;}.thumb.thumb-contain.jsx-3808261869{background-size:contain;}.video-fact-icon.jsx-3808261869{position:absolute;top:6px;right:6px;}img.jsx-3808261869{display:block;height:100%;margin:0;padding:0;width:100%;}.main-img.jsx-3808261869{opacity:0;}.overlay.jsx-3808261869{position:absolute;left:0px;top:0px;}.hot-overlay.jsx-3808261869{left:1px;bottom:1px;position:absolute;}@media (min-width:768px){.hot-overlay.jsx-3808261869{width:70px;height:32px;}.hot-overlay.hero.jsx-3808261869{width:80px;height:37px;}}@media (max-width:767px){.hot-overlay.jsx-3808261869{width:60px;height:27px;}.hot-overlay.hero.jsx-3808261869{width:60px;height:27px;}}
#   </style>
#   <style id="__jsx-3501530503">
#    .main.jsx-3501530503{display:block;margin-bottom:20px;}@media (max-width:767px){.main.main-0.jsx-3501530503 .thumb{border:0;border-radius:0 !important;}}.body.jsx-3501530503{margin-top:12px;}.info.jsx-3501530503{font-size:13px;margin-bottom:3px;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;list-style-type:none;}.comment.jsx-3501530503{margin-left:8px;}.comment.jsx-3501530503 svg{display:inline-block;vertical-align:middle;}.comment.jsx-3501530503 .comment-count.jsx-3501530503{font-weight:600;margin-left:5px;}.subbrand.jsx-3501530503{margin-right:6px;}.subbrand.jsx-3501530503 .subbrand-img.jsx-3501530503{width:24px;}.first.jsx-3501530503 .thread-title.jsx-3501530503{font-size:22px;line-height:32px;overflow:visible;-webkit-line-clamp:unset;}.second.jsx-3501530503{height:100%;overflow:hidden;border-radius:6px;}@media (min-width:768px){.second.jsx-3501530503{background-image:var(--second-featured-threads-background);}}.second.jsx-3501530503 .thumb{border-radius:8px 8px 0 0 !important;}.second.jsx-3501530503 .thread-title.jsx-3501530503{line-height:20px;margin-bottom:12px;overflow:visible;-webkit-line-clamp:unset;}@media (min-width:768px){.second.jsx-3501530503 .body.jsx-3501530503{padding:0 16px 12px;}}.second.jsx-3501530503 .body.jsx-3501530503 .excerpt.jsx-3501530503{font-size:16px;line-height:inherit;display:none;}@media (min-width:768px){.second.jsx-3501530503 .body.jsx-3501530503 .excerpt.jsx-3501530503{overflow:hidden;display:-webkit-box;-webkit-box-orient:vertical;-webkit-line-clamp:7;}}
#   </style>
#   <style id="__jsx-3834913322">
#    .featured-threads.jsx-3834913322{margin-bottom:10px;}ol.jsx-3834913322{margin-left:-8px;margin-right:-8px;display:grid;grid-template:"prm1 prm1" "snd1 prm2" "snd2 snd3"/1fr 1fr;}@media (min-width:768px){ol.jsx-3834913322{display:grid;grid-template:"prm1 prm1 prm2" "snd1 snd2 snd3"/1fr 1fr 1fr;}}li.jsx-3834913322{overflow:hidden;padding-left:8px;padding-right:8px;}li.jsx-3834913322:nth-child(1){grid-area:prm1;}li.jsx-3834913322:nth-child(2){grid-area:prm2;}li.jsx-3834913322:nth-child(3){grid-area:snd1;}li.jsx-3834913322:nth-child(4){grid-area:snd2;}li.jsx-3834913322:nth-child(5){grid-area:snd3;}
#   </style>
#   <style id="__jsx-2864466674">
#    .header-promo-img.jsx-2864466674{min-width:100%;min-height:100%;width:auto;height:auto;}@media (max-width:767px){.header-promo-img.desktop.jsx-2864466674{display:none;}}@media (min-width:768px){.header-promo-img.desktop.jsx-2864466674{display:block;}}@media (max-width:767px){.header-promo-img.mobile.jsx-2864466674{display:block;}}@media (min-width:768px){.header-promo-img.mobile.jsx-2864466674{display:none;}}.sidebar-container.jsx-2864466674{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}
#   </style>
#   <style id="__jsx-2015658151">
#    .pro-container.jsx-2015658151{position:relative;}.pro-container.withBorder.jsx-2015658151{border:1px solid var(--border-light);}@media (max-width:767px){.pro-container.mobileOnly.jsx-2015658151{display:block;}.pro-container.desktopOnly.jsx-2015658151{display:none;}}@media (min-width:768px){.pro-container.mobileOnly.jsx-2015658151{display:none;}.pro-container.desktopOnly.jsx-2015658151{display:block;}}.java-logo.jsx-2015658151{width:30px;bottom:0;right:0;position:absolute;}
#   </style>
#   <style id="__jsx-2206250852">
#    .thread.jsx-2206250852{position:relative;}.thread.jsx-2206250852:before{content:"";width:7px;height:7px;border-radius:50%;left:-20px;top:6px;position:absolute;display:block;background-color:var(--primary-color);}.item.jsx-2206250852{margin-bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}.img.jsx-2206250852 .thumb-wrapper{width:120px;}.thread-title.jsx-2206250852{font-size:14px;line-height:20px;margin-right:12px;margin-bottom:0;display:-webkit-box;-webkit-line-clamp:3;-webkit-box-orient:vertical;overflow:hidden;}
#   </style>
#   <style id="__jsx-446559669">
#    @media (max-width:576px){.subsection.jsx-446559669{padding-top:16px;border-top:1px solid var(--primary-border);}}.listing-groups.jsx-446559669{border:1px dotted var(--primary-color);border-top:0;border-right:0;border-radius:0 0 0 30px;padding:0 16px 16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.listing-groups.jsx-446559669 .listing.jsx-446559669:nth-child(2){margin-left:20px;}@media (max-width:576px){.listing-groups.jsx-446559669 .listing.jsx-446559669:nth-child(2){margin-left:10px;}}@media (max-width:576px){.listing-groups.jsx-446559669 .listing.jsx-446559669{min-width:260px;}}
#   </style>
#   <style id="__jsx-870675565">
#    .header.jsx-870675565{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.header.jsx-870675565 svg{margin-right:12px;}.header.jsx-870675565 .section-heading.jsx-870675565{margin-bottom:0;}.threads.jsx-870675565{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin:0 -12px;}.thread.jsx-870675565{padding:24px 12px 0;-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.thread-index.jsx-870675565{color:var(--trending-index-text);font-size:42px;font-weight:800;line-height:1;-webkit-flex:0 0 64px;-ms-flex:0 0 64px;flex:0 0 64px;opacity:0.48;}.thread-content.jsx-870675565{-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}@media (max-width:500px){.thread.jsx-870675565{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;}}
#   </style>
#   <style id="__jsx-1673213166">
# ...
#        </i>
#       </button>
#      </div>
#     </div>
#     <div class="jsx-3345895307 main">
#      <div class="jsx-3345895307 shortcuts">
#       <div class="jsx-3662561806 main">
#        <ol class="jsx-3662561806 list">
#         <li class="jsx-3662561806 item active">
#          <a class="jsx-3662561806" href="https://tinhte.vn/">
#           Tin mới
#          </a>
#         </li>
#         <li class="jsx-3662561806 item">
#          <a class="jsx-3662561806" href="https://tinhte.vn/resources/">
#           Sản phẩm công nghệ mới
#          </a>
#         </li>
#         <li class="jsx-3662561806 item">
#          <a class="jsx-3662561806" href="https://tinhte.vn/km/">
#           Khuyến mãi
#          </a>
#         </li>
#         <li class="jsx-3662561806 item">
#          <a class="jsx-3662561806" href="https://tinhte.vn/events/">
#           Sự kiện
#          </a>
#         </li>
#         <li class="jsx-3662561806 item">
#          <a class="jsx-3662561806" href="https://www.youtube.com/user/tinhtevideo/">
#           Video
#          </a>
#         </li>
#        </ol>
#       </div>
#      </div>
#      <div class="jsx-3345895307 links">
#       <ol class="jsx-127126660 main">
#        <li class="jsx-127126660 item">
#         <div class="jsx-121732950 main active">
#          <h3 class="jsx-121732950 heading">
#           Tinh tế
#          </h3>
#          <ol class="jsx-121732950 list">
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/threads/noi-quy-dien-dan.20/">
#             Nội quy diễn đàn
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/threads/thoa-thuan-cung-cap-su-dung-dich-vu.2864413/">
#             Thỏa thuận sử dụng dịch vụ
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/forums/gop-y-xay-dung-dien-dan.81/">
#             Góp ý
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/hotro/">
#             Hỗ trợ, hướng dẫn
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/quangcao/">
#             Liên hệ quảng cáo
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://feeds.feedburner.com/tinhte/">
#             Tinh tế RSS
#            </a>
#           </li>
#          </ol>
#         </div>
#        </li>
#        <li class="jsx-127126660 item">
#         <div class="jsx-121732950 main">
#          <h3 class="jsx-121732950 heading">
#           Cộng đồng
#          </h3>
#          <ol class="jsx-121732950 list">
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/dienthoai/">
#             Điện thoại
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/maytinh/">
#             Máy tính
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/camera/">
#             Camera
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/xe/">
#             Xe
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/khcn/">
#             Khoa học công nghệ
#            </a>
#           </li>
#          </ol>
#         </div>
#        </li>
#        <li class="jsx-127126660 item">
#         <div class="jsx-121732950 main">
#          <h3 class="jsx-121732950 heading">
#           Nhật Tảo
#          </h3>
#          <ol class="jsx-121732950 list">
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/dien-thoai.543/">
#             Mua bán điện thoại
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/may-tinh.553/">
#             Mua bán máy tính
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/may-tinh-bang.548/">
#             Mua bán máy tính bảng
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/camera.556/">
#             Mua bán camera
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/dong-ho-thong-minh.585/">
#             Mua bán đồng hồ thông minh
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/xe.532/">
#             Mua bán xe
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/dien-may.602/">
#             Mua bán điện máy
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://nhattao.com/f/sim-dien-thoai.533/">
#             Mua bán sim, sim 3G
#            </a>
#           </li>
#          </ol>
#         </div>
#        </li>
#        <li class="jsx-127126660 item">
#         <div class="jsx-121732950 main">
#          <h3 class="jsx-121732950 heading">
#           Liên kết
#          </h3>
#          <ol class="jsx-121732950 list">
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://tinhte.vn/cafe/">
#             Cà phê Tinh tế
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://khacten.com/">
#             Khắc tên
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://chimua.vn/">
#             ChiMua.vn
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="http://www.1tudien.com/">
#             1Tudien
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.nhaccuatui.com/">
#             NhacCuaTui
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.5giay.vn/">
#             5Giay
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.webtretho.com/">
#             Webtretho
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://bkvn.com/">
#             Biker Vietnam
#            </a>
#           </li>
#          </ol>
#         </div>
#        </li>
#        <li class="jsx-127126660 item">
#         <div class="jsx-121732950 main">
#          <h3 class="jsx-121732950 heading">
#           Theo dõi chúng tôi
#          </h3>
#          <ol class="jsx-121732950 list">
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.facebook.com/tinhte/">
#             <svg class="jsx-121732950" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M20 4.882v14.232a.88.88 0 0 1-.882.882h-4.079v-6.192h2.079l.31-2.415h-2.392V9.846c0-.7.193-1.175 1.196-1.175h1.279v-2.16a17.19 17.19 0 0 0-1.865-.097c-1.842 0-3.107 1.125-3.107 3.193v1.782h-2.085v2.415h2.085V20H4.882A.884.884 0 0 1 4 19.118V4.882C4 4.396 4.396 4 4.882 4h14.232c.49 0 .886.396.886.882z">
#              </path>
#             </svg>
#             Facebook
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.youtube.com/user/tinhtevideo/">
#             <svg class="jsx-121732950" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M19.64 7.878c-.184-.74-.724-1.322-1.41-1.52C16.986 6 12 6 12 6s-4.986 0-6.23.359c-.686.197-1.226.78-1.41 1.519-.333 1.34-.333 4.134-.333 4.134s0 2.795.333 4.135c.184.739.724 1.297 1.41 1.494C7.014 18 12 18 12 18s4.986 0 6.23-.359a2.046 2.046 0 0 0 1.41-1.494c.333-1.34.333-4.135.333-4.135s0-2.795-.333-4.134zm-9.27 6.672V9.475l4.167 2.537-4.168 2.538z">
#              </path>
#             </svg>
#             Youtube
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://www.flickr.com/photos/tinhtephoto/">
#             <svg class="jsx-121732950" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M18.286 4H5.714C4.768 4 4 4.768 4 5.714v12.572C4 19.232 4.768 20 5.714 20h12.572c.946 0 1.714-.768 1.714-1.714V5.714C20 4.768 19.232 4 18.286 4zM9.16 14.25a2.266 2.266 0 0 1-2.268-2.268A2.266 2.266 0 0 1 9.16 9.714a2.266 2.266 0 0 1 2.268 2.268A2.266 2.266 0 0 1 9.16 14.25zm5.678 0a2.266 2.266 0 0 1-2.268-2.268 2.266 2.266 0 0 1 2.268-2.268 2.266 2.266 0 0 1 2.268 2.268 2.266 2.266 0 0 1-2.268 2.268z">
#              </path>
#             </svg>
#             Flickr
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://twitter.com/tinhtefan/">
#             <svg class="jsx-121732950" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M18.355 9.24c.01.142.01.284.01.426 0 4.337-3.299 9.334-9.33 9.334A9.264 9.264 0 0 1 4 17.527c.264.03.518.041.792.041a6.566 6.566 0 0 0 4.071-1.402 3.285 3.285 0 0 1-3.066-2.275c.203.03.406.051.62.051.294 0 .588-.04.862-.112a3.28 3.28 0 0 1-2.63-3.22v-.04c.437.244.945.396 1.483.417A3.278 3.278 0 0 1 4.67 8.255c0-.61.162-1.168.447-1.656a9.32 9.32 0 0 0 6.761 3.433 3.705 3.705 0 0 1-.081-.752A3.278 3.278 0 0 1 15.077 6a3.27 3.27 0 0 1 2.395 1.036 6.455 6.455 0 0 0 2.081-.792 3.271 3.271 0 0 1-1.441 1.808c.66-.072 1.3-.254 1.888-.508a7.05 7.05 0 0 1-1.645 1.696z">
#              </path>
#             </svg>
#             Twitter
#            </a>
#           </li>
#           <li class="jsx-121732950 item">
#            <a class="jsx-121732950" href="https://plus.google.com/+tinhte/">
#             <svg class="jsx-121732950" height="24" width="24" xmlns="http://www.w3.org/2000/svg">
#              <path d="M12 4c-4.416 0-8 3.584-8 8s3.584 8 8 8 8-3.584 8-8-3.584-8-8-8zM9.72 16c-2.22 0-4-1.79-4-4s1.78-4 4-4c1.009 0 1.938.355 2.677 1.042l-1.084 1.052c-.426-.417-1.01-.617-1.594-.617-1.384 0-2.49 1.146-2.49 2.52s1.103 2.52 2.49 2.52c1.052 0 2.094-.617 2.262-1.72H9.719v-1.374h3.771c.042.219.062.438.062.667 0 2.284-1.533 3.91-3.833 3.91zm7.425-3.426v1.145H16v-1.145h-1.145V11.43H16v-1.145h1.145v1.145h1.136v1.145h-1.136z">
#              </path>
#             </svg>
#             Google+
#            </a>
#           </li>
#          </ol>
#         </div>
#        </li>
#       </ol>
#      </div>
#      <div class="jsx-3345895307 infos">
#       <ul class="jsx-445989696 main">
#        <li class="jsx-445989696 item">
#         Chịu trách nhiệm nội dung: Trần Mạnh Hiệp
#        </li>
#        <li class="jsx-445989696 item">
#         ©
#         <!-- -->
#         2022
#         <!-- -->
#         Công ty Cổ phần MXH Tinh Tế
#        </li>
#        <li class="jsx-445989696 item">
#         Địa chỉ: 209 Đường Nam Kỳ Khởi Nghĩa, Phường 7, Quận 3, TP.HCM
#        </li>
#        <li class="jsx-445989696 item">
#         Số điện thoại: 02862713156
#        </li>
#        <li class="jsx-445989696 item">
#         MST: 0313255119
#        </li>
#        <li class="jsx-445989696 item">
#         Giấy phép thiết lập MXH số 11/GP-BTTTT, Ký ngày: 08/01/2019
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div>
#     </div>
#    </div>
#    <iframe class="ApiLoader" data-user-id="0" sandbox="allow-same-origin allow-scripts" src="" style="display:block;height:0;width:0">
#    </iframe>
#    <div class="Toastify">
#    </div>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"pageProps":{
nhỏ như hạt đậu và một cái máy ảnh với  kích thước cảm biến “đầy đủ”. Điều mình muốn chia sẻ ở đây là liệu camera trên cái điện thoại…\u003c/div\u003e\n\n\t\t\t\u003cdiv class=\"extra\"\u003e\n\t\t\t\t\u003cspan class=\"host\"\u003e\n\t\t\t\t\t\u003ci class=\"is-secure-indicator fa fa-lock\"\u003e\u003c/i\u003e tinhte.vn\n\t\t\t\t\u003c/span\u003e\n\t\t\t\u003c/div\u003e\n\t\t\u003c/div\u003e\n\t\u003c/div\u003e\n\u003c/a\u003e","post_body_plain_text":"Ảnh từ bộ máy ảnh 30 củ so với điện thoại 30 củ thì sẽ như thế nào :grin: \nhttps://tinhte.vn/thread/moi-moi-nguoi-cung-so-sanh-anh-chup-iphone-13-pro-va-sony-a7ii.3483386/","post_like_count":2,"post_is_liked":false,"attachments":[{"attachment_id":5426432,"attachment_download_count":0,"filename":"72404299-9307-477A-B553-82896AB151ED.jpg","links":{"permalink":"https://photo2.tinhte.vn/data/attachment-files/2022/03/5896439_72404299-9307-477A-B553-82896AB151ED.jpg","data":"https://tinhte.vn/appforo/index.php?attachments/5426432/data\u0026oauth_token=0%2C1646858828%2C5b3e01507b7ca7b9ae08e7aea18b3895%2Clxi7g2zolu","thumbnail":"https://imgproxy.k7.tinhte.vn/zb98GOAv9sdiw_6ECiWRBiT8eLKJZ-dQW4rRNoTzbds/h:400/plain/https://photo2.tinhte.vn/data/attachment-files/2022/03/5896439_72404299-9307-477A-B553-82896AB151ED.jpg","post":"https://tinhte.vn/appforo/index.php?posts/62176478/\u0026oauth_token=0%2C164685 ...
#   </script>
#  </body>
# </html>

# %%
first_header= soup.find("h2")
first_header

# %%
headers = soup.find_all("h2")
print(headers)
# Out:
# []

# %%
first_header = soup.find(["h1","h2"])

# %%
hearders = soup.find_all(["h1",'h2'])
print(hearders)
# Out:
# []

# %%
paragraph = soup.find_all("p", attrs={"id": "paragraph-id"})
print(paragraph)
# Out:
# []

# %%
body = soup.find('body')
div = body.find('div')
header = div.find('h1')
header

# %%
import re

# %%
paragraph = soup.find_all("p", string=re.compile("Some"))
paragraph
# Out:
# []

# %%
headers = soup.find_all("h2", string=re.compile("(H|h)eader"))
hearders
# Out:
# []

# %%
content  = soup.select("div p")
content
# Out:
# [<p class="jsx-3470779898 create-fact">Tạo fact mới</p>,
#  <p class="jsx-4083475239 load-more">Bấm vào để xem nhiều hơn</p>,
#  <p class="jsx-3501530503 excerpt">Như anh em cũng đã biết Google Home Mini là một sản phẩm loa thông minh của Google, ngoài việc là một chiếc loa điều khiển bằng giọng nói nó còn là một thiết bị có thể kết nối wifi và điều khiển các thiết bị điện tử thông minh trong căn phòng của chúng ta. Đợt 2019 Google Home Mini nổi lên như một “hiện tượng” ở Việt Nam khi mà chính thức hỗ trợ tiếng Việt, việc điều khiển Google Home Mini khiến nhiều anh em thích thú và mình thấy đợt ấy bán rất chạy, nhưng rồi Google không còn hỗ trợ tiếng Việt nữa…</p>,
#  <p class="jsx-446559669 section-heading">Xem nhanh</p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Vespa 946 Christian Dior sang tay với giá hơn 1,1 tỷ đồng, chênh 400 triệu so với giá gốc">Vespa 946 Christian Dior sang tay với giá hơn 1,1 tỷ đồng, chênh 400 triệu so với giá gốc</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Tinh Tế Daily #1">Tinh Tế Daily #1</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Đã có Android 12L chính thức cho điện thoại Pixel, mời anh em cập nhật">Đã có Android 12L chính thức cho điện thoại Pixel, mời anh em cập nhật</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Mẹo nhỏ dành cho anh em tự quay vlog bằng iPhone">Mẹo nhỏ dành cho anh em tự quay vlog bằng iPhone</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Apple ngừng sản xuất iMac 27-inch">Apple ngừng sản xuất iMac 27-inch</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Bạn cần phải trả 7999 USD nếu muốn sở hữu Mac Studio “max option”">Bạn cần phải trả 7999 USD nếu muốn sở hữu Mac Studio “max option”</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Tổng hợp deal khuyến mãi 09/03">Tổng hợp deal khuyến mãi 09/03</span></p>,
#  <p class="jsx-2206250852 thread-title"><span class="jsx-2206250852" title="Samsung xác nhận bị hacker đánh cắp mã nguồn của các máy Galaxy">Samsung xác nhận bị hacker đánh cắp mã nguồn của các máy Galaxy</span></p>,
#  <p class="jsx-870675565 thread-title">Nga sẽ "ngắt kết nối với Internet toàn cầu" vào ngày 11/3</p>,
#  <p class="jsx-870675565 author">mig0</p>,
#  <p class="jsx-870675565 thread-title">Chip M1 Ultra là bằng chứng cho tuyên bố Apple Silicon "scalable" 2 năm trước</p>,
#  <p class="jsx-870675565 author">Duy Luân</p>,
#  <p class="jsx-870675565 thread-title">Mình còn làm gì với Google Home Mini tại năm 2022?</p>,
#  <p class="jsx-870675565 author">lexcuong</p>,
#  <p class="jsx-870675565 thread-title">Review Loa Blitzwolf BW-WA3 Công Suất 100W - Mà Giá Chỉ 1.1 Triệu Thật Hay Đùa ?</p>,
#  <p class="jsx-870675565 author">TaChaBa</p>,
#  <p class="jsx-870675565 thread-title">Review Những điều thích và không thích trên apple watch sr6 bản gps</p>,
#  <p class="jsx-870675565 author">dragonfruit</p>,
#  <p class="jsx-870675565 thread-title">Review những bài Review! Viết Review để làm gì?</p>,
#  <p class="jsx-870675565 author">tung009</p>,
#  <p class="jsx-1673213166 creator-name">Góc cô đơn</p>,
#  <p class="jsx-1673213166 creator-name">lexcuong</p>,
#  <p class="jsx-1673213166 creator-name">totora</p>,
#  <p class="jsx-1673213166 creator-name">TaChaBa</p>,
#  <p class="jsx-1673213166 creator-name">huyhoang@95</p>,
#  <p class="jsx-3832343691 info"><span class="jsx-3832343691 duration">41:2</span><span class="jsx-3832343691 view"><span>1.457</span> lượt xem</span></p>,
p>,
#  <p class="jsx-2238569880 excerpt hidden-sm">Mời anh em chia sẻ thêm những ưu đãi giảm giá từ các trang thương mại điện tử lớn tại Việt Nam. Những deal nổi bật được cập nhật hàng ngày có giá trị theo giờ, theo ngày hoặc đến khi hết sản phẩm.</p>,
#  <p class="jsx-2238569880 excerpt hidden-sm">Dự án được thực hiện bởi Scan of the Month, nhóm sử dụng công nghệ chụp cắt lớp (computed tomography scanning hay còn gọi là CT) thường thấy ở các cơ sở y tế…</p>,
#  <p class="jsx-2238569880 excerpt hidden-sm">Microsoft chỉ bán được 2.3 triệu máy Xbox ở Nhật Bản trong 20 năm qua, trong số đó chỉ duy nhất Xbox 360 là mẫu console cán mốc 1 triệu máy tính tới nay.
#
#  Xbox không phổ biến ở Nhật Bản.</p>,
#  <p class="jsx-2238569880 excerpt hidden-sm">McDonald's, Coca-Cola, PepsiCo, Starbucks là những tập đoàn Mỹ lớn nhất vừa đưa ra động thái thông báo ngừng hoạt động ở Nga sau chiến dịch quân sự ở Ukraine.</p>,
#  <p class="jsx-2238569880 excerpt hidden-sm">Khi ra mắt con Apple M1, Apple nói là họ làm Apple Silicon để có thể dễ dàng “scalable”. Chúng ta đã thấy sơ sơ vụ này qua M1 Pro và M1 Max, nhưng chưa rõ ràng lắm.</p>,
#  <p class="jsx-2445017959 title" title="Mua sắm thông minh">Mua sắm thông minh</p>,
#  <p class="jsx-2445017959 title" title="Phím cơ">Phím cơ</p>,
#  <p class="jsx-2445017959 title" title="Sống khỏe mùa dịch">Sống khỏe mùa dịch</p>,
#  <p class="jsx-2445017959 title" title="Raspberry Pi">Raspberry Pi</p>,
#  <p class="jsx-2445017959 title" title="Viettel">Viettel</p>,
#  <p class="jsx-2445017959 title" title="Android">Android</p>]

# %%
paragraphs = soup.select("he ~ p")
print(paragraphs)
# Out:
# []

# %%
bold_text = soup.select("p#paragraph-id b")
bold_text
# Out:
# []

# %%
paragraphs = soup.select("body < p")
paragraphs
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# c:\VSCode\test\beauti_soup.ipynb Cell 19' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/VSCode/test/beauti_soup.ipynb#ch0000019?line=0'>1</a> paragraphs = soup.select("body < p")
#       <a href='vscode-notebook-cell:/c%3A/VSCode/test/beauti_soup.ipynb#ch0000019?line=1'>2</a> paragraphs
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\bs4\element.py:1949, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1943'>1944</a> if soupsieve is None:
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1944'>1945</a>     raise NotImplementedError(
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1945'>1946</a>         "Cannot execute CSS selectors because the soupsieve package is not installed."
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1946'>1947</a>     )
# -> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1948'>1949</a> results = soupsieve.select(selector, self, namespaces, limit, **kwargs)
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1950'>1951</a> # We do this because it's more consistent and because
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1951'>1952</a> # ResultSet.__getattr__ has a helpful error message.
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/bs4/element.py?line=1952'>1953</a> return ResultSet(None, results)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\__init__.py:144, in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=131'>132</a> def select(
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=132'>133</a>     select: str,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=133'>134</a>     tag: 'bs4.Tag',
#    (...)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=139'>140</a>     **kwargs: Any
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=140'>141</a> ) -> List['bs4.Tag']:
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=141'>142</a>     """Select the specified tags."""
# --> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=143'>144</a>     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\__init__.py:67, in compile(pattern, namespaces, flags, custom, **kwargs)
#      <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=63'>64</a>         raise ValueError("Cannot process 'custom' argument on a compiled selector list")
#      <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=64'>65</a>     return pattern
# ---> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/__init__.py?line=66'>67</a> return cp._cached_css_compile(pattern, ns, cs, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_parser.py:222, in _cached_css_compile(pattern, namespaces, custom, flags)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=212'>213</a> """Cached CSS compile."""
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=214'>215</a> custom_selectors = process_custom(custom)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=215'>216</a> return cm.SoupSieve(
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=216'>217</a>     pattern,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=217'>218</a>     CSSParser(
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=218'>219</a>         pattern,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=219'>220</a>         custom=custom_selectors,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=220'>221</a>         flags=flags
# --> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=221'>222</a>     ).process_selectors(),
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=222'>223</a>     namespaces,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=223'>224</a>     custom,
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=224'>225</a>     flags
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=225'>226</a> )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_parser.py:1159, in CSSParser.process_selectors(self, index, flags)
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1155'>1156</a> def process_selectors(self, index: int = 0, flags: int = 0) -> ct.SelectorList:
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1156'>1157</a>     """Process selectors."""
# -> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1158'>1159</a>     return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_parser.py:985, in CSSParser.parse_selectors(self, iselector, index, flags)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=982'>983</a> try:
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=983'>984</a>     while True:
# --> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=984'>985</a>         key, m = next(iselector)
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=986'>987</a>         # Handle parts
#     <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=987'>988</a>         if key == "at_rule":
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\soupsieve\css_parser.py:1152, in CSSParser.selector_iter(self, pattern)
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1149'>1150</a>         else:
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1150'>1151</a>             msg = "Invalid character {!r} position {}".format(c, index)
# -> <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1151'>1152</a>         raise SelectorSyntaxError(msg, self.pattern, index)
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1152'>1153</a> if self.debug:  # pragma: no cover
#    <a href='file:///c%3A/Users/levan/AppData/Local/Programs/Python/Python310/lib/site-packages/soupsieve/css_parser.py?line=1153'>1154</a>     print('## END PARSING')
#
# SelectorSyntaxError: Invalid character '<' position 5
#   line 1:
# body < p
#      ^

# %%
soup.select("[align=middle]")
# Out:
# []

# %%
hearder = soup.find("h2")
hearder
# Out:
# <h2 class="cf-subheadline"><span data-translate="managed_checking_msg">We are checking your browser...</span> voz.vn</h2>

# %%
div = soup.find("div")
print(div.prettify())
print(div.get_text())
# Out:
# <div id="cf-wrapper">
#  <div class="cf-alert cf-alert-error cf-cookie-error" data-translate="enable_cookies" id="cookie-alert">
#   Please enable cookies.
#  </div>
#  <div class="cf-error-details-wrapper" id="cf-error-details">
#   <div class="cf-wrapper cf-header cf-error-overview">
#    <h1 data-translate="managed_challenge_headline">
#     Please wait...
#    </h1>
#    <h2 class="cf-subheadline">
#     <span data-translate="managed_checking_msg">
#      We are checking your browser...
#     </span>
#     voz.vn
#    </h2>
#   </div>
#   <div class="cf-section cf-highlight cf-captcha-container">
#    <div class="cf-wrapper">
#     <div class="cf-columns two">
#      <div class="cf-column">
#       <div class="cf-highlight-inverse cf-form-stacked">
#        <form action="/?__cf_chl_f_tk=A2whRMiFHlJ0BneS6V5vJMuIrhMwf0TUbXcfVK0DKd8-1646855471-0-gaNycGzNByU" class="challenge-form managed-form" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#         <div id="cf-please-wait">
#          <div id="spinner">
#           <div id="cf-bubbles">
#            <div class="bubbles">
#            </div>
#            <div class="bubbles">
#            </div>
#            <div class="bubbles">
#            </div>
#           </div>
#          </div>
#          <p data-translate="please_wait" id="cf-spinner-please-wait">
#           Please stand by, while we are checking your browser...
#          </p>
#          <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">
#           Redirecting...
#          </p>
#         </div>
#         <input name="md" type="hidden" value="OTNPS90NjZyHAHEwZyOLoKtF4rz04P70f7z6ld_kkBo-1646855471-0-AaNC15epDDPqe_boHTF5yNr9zzhNns3IR-qbyJdk6_WZBctT2BV-0rxlE_ed5ldzVs3eDpsbI0cyr9_q8EIQcnKIGAbI2d-mHFZLIPL3VYe3eJVkdXfIxZGpXWMYgOXsvtlo4bxk1uTmEiF2-hBT-wnCX8FIOtQyiqFQ1r8jxMIvSyj1D2PXmBxw_Q3bWTzbh_D1FmwFGblxMvMA1B6P_oEpt8a5aBp0KivYKfRna5oC5VqPb3KJhYeKxj0uhq9ckEHerAYyA3O7BDF3lrov7VodianrWm36NADRjq7DwPAMigMHgNJ_GA4V5TNDSViM43rNPd-AegdCnJW1E_FcA0VpgbYkKTWq9uYnnIU1fNoJz7eLFynszjc0t3yretrrM8O_I8xWOpYshSnOcwQ9WwSI6OmttaZW7AUXVSCR1R2i70JqBhSCnQ6LHwBH6EOJvJhZ23QAc3SVIeH1PnfgtZNiN0DpRP8QUWN24PgutvMkavQz7VD_gDEGg5ww6fii3xStjgL-EBX5KtQdp7-STlqWEfWG8SxYApqtM1JyTq20xKVYExNkYnAZWZhqCZXNNZyIbn8OIZeaFAylRAmz2GfJ3dXYW8q7xldD-qX77oFGio2avf4NS-TU61oEoNrE0w0IJkflgTVq_3X-wWYrehbJ6PIZHL8yqCLoUuxHQ1C-ycYhGPv8XZRH2GP0MQhRN9Qz8Jx8aGaZPR3mqOmlbYWhO04kpU4w_kP2ulgkLjn1WU6sYa9lzrStJ_ESJq4Mo_otuYcQ5ay85EmVTztBW6qL1cEKAmolRP1L0VlITB9WkO4qQBc2V5bsVACtj1N06Ldg4Ql9sOnW6IQinogquS-c2b6dRVoJyw4wZxvxAuyi6kSW77DU6646V6dVUhA4ngvx3G6u99mVZE-Fwhfempc"/>
#         <input name="r" type="hidden" value="7mtdsKdvDD4P2m1C7cMH6GL9hlCoiPiwNDRA0vniRI8-1646855471-0-..."/>
#         <input name="vc" type="hidden" value="be35e3a919b332874d52f42f885f1a83"/>
#         <noscript class="cf-captcha-info" id="cf-captcha-bookmark">
#          <h1 data-translate="turn_on_js" style="color:#bd2426;">
#           Please turn JavaScript on and reload the page.
#          </h1>
#         </noscript>
#         <div class="cookie-warning" data-translate="turn_on_cookies" id="no-cookie-warning" style="display:none">
#          <p data-translate="turn_on_cookies" style="color:#bd2426;">
#           Please enable Cookies and reload the page.
#          </p>
#         </div>
#         <script type="text/javascript">
#          //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#         </script>
#         <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/h/transparent.gif?ray=6e965806cd4787d2')">
#         </div>
#        </form>
#        <script type="text/javascript">
#         //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=6e965806cd4787d2");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src="/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=6e965806cd4787d2";
#
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.indexOf('?') !== -1 ? '?' : location.search;
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/?__cf_chl_rt_tk=A2whRMiFHlJ0BneS6V5vJMuIrhMwf0TUbXcfVK0DKd8-1646855471-0-gaNycGzNByU" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#        </script>
#       </div>
#      </div>
#      <div class="cf-column">
#       <div class="cf-screenshot-container">
#        <span class="cf-no-screenshot">
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="cf-section cf-wrapper">
#    <div class="cf-columns two">
#     <div class="cf-column">
#      <h2 data-translate="why_captcha_headline">
#       Why do I have to complete a CAPTCHA?
#      </h2>
#      <p data-translate="why_captcha_detail">
#       Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.
#      </p>
#     </div>
#     <div class="cf-column">
#      <h2 data-translate="resolve_captcha_headline">
#       What can I do to prevent this in the future?
#      </h2>
#      <p data-translate="resolve_captcha_antivirus">
#       If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.
#      </p>
#      <p data-translate="resolve_captcha_network">
#       If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.
#      </p>
#     </div>
#    </div>
#   </div>
#   <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#    <p class="text-13">
#     <span class="cf-footer-item sm:block sm:mb-1">
#      Cloudflare Ray ID:
#      <strong class="font-semibold">
#       6e965806cd4787d2
#      </strong>
#     </span>
#     <span class="cf-footer-separator sm:hidden">
#      •
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1">
#      <span>
#       Your IP
#      </span>
#      : 58.187.143.1
#     </span>
#     <span class="cf-footer-separator sm:hidden">
#      •
#     </span>
#     <span class="cf-footer-item sm:block sm:mb-1">
#      <span>
#       Performance &amp; security by
#      </span>
#      <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">
#       Cloudflare
#      </a>
#     </span>
#    </p>
#   </div>
#   <!-- /.error-footer -->
#  </div>
# </div>
#
#
# Please enable cookies.
#
#
# Please wait...
# We are checking your browser... voz.vn
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Please stand by, while we are checking your browser...
# Redirecting...
#
#
#
#
#
# Please turn JavaScript on and reload the page.
#
#
# Please enable Cookies and reload the page.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Why do I have to complete a CAPTCHA?
# Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.
#
#
# What can I do to prevent this in the future?
# If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.
# If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.
#
#
#
#
#
# Cloudflare Ray ID: 6e965806cd4787d2
# •
# Your IP: 58.187.143.1
# •
# Performance & security by Cloudflare

# %%
link = soup.find("a")
link = ['href']

# %%
paragraphs = soup.select("p#paragraph-id")
paragraph[0]['id']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\VSCode\test\beauti_soup.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/VSCode/test/beauti_soup.ipynb#ch0000024?line=0'>1</a> paragraphs = soup.select("p#paragraph-id")
# ----> <a href='vscode-notebook-cell:/c%3A/VSCode/test/beauti_soup.ipynb#ch0000024?line=1'>2</a> paragraph[0]['id']
#
# IndexError: list index out of range

# %%
soup.body.div.h1.string
print(soup.body.prettify())
# Out:
# <body>
#  <div id="cf-wrapper">
#   <div class="cf-alert cf-alert-error cf-cookie-error" data-translate="enable_cookies" id="cookie-alert">
#    Please enable cookies.
#   </div>
#   <div class="cf-error-details-wrapper" id="cf-error-details">
#    <div class="cf-wrapper cf-header cf-error-overview">
#     <h1 data-translate="managed_challenge_headline">
#      Please wait...
#     </h1>
#     <h2 class="cf-subheadline">
#      <span data-translate="managed_checking_msg">
#       We are checking your browser...
#      </span>
#      voz.vn
#     </h2>
#    </div>
#    <div class="cf-section cf-highlight cf-captcha-container">
#     <div class="cf-wrapper">
#      <div class="cf-columns two">
#       <div class="cf-column">
#        <div class="cf-highlight-inverse cf-form-stacked">
#         <form action="/?__cf_chl_f_tk=A2whRMiFHlJ0BneS6V5vJMuIrhMwf0TUbXcfVK0DKd8-1646855471-0-gaNycGzNByU" class="challenge-form managed-form" enctype="application/x-www-form-urlencoded" id="challenge-form" method="POST">
#          <div id="cf-please-wait">
#           <div id="spinner">
#            <div id="cf-bubbles">
#             <div class="bubbles">
#             </div>
#             <div class="bubbles">
#             </div>
#             <div class="bubbles">
#             </div>
#            </div>
#           </div>
#           <p data-translate="please_wait" id="cf-spinner-please-wait">
#            Please stand by, while we are checking your browser...
#           </p>
#           <p data-translate="redirecting" id="cf-spinner-redirecting" style="display:none">
#            Redirecting...
#           </p>
#          </div>
#          <input name="md" type="hidden" value="OTNPS90NjZyHAHEwZyOLoKtF4rz04P70f7z6ld_kkBo-1646855471-0-AaNC15epDDPqe_boHTF5yNr9zzhNns3IR-qbyJdk6_WZBctT2BV-0rxlE_ed5ldzVs3eDpsbI0cyr9_q8EIQcnKIGAbI2d-mHFZLIPL3VYe3eJVkdXfIxZGpXWMYgOXsvtlo4bxk1uTmEiF2-hBT-wnCX8FIOtQyiqFQ1r8jxMIvSyj1D2PXmBxw_Q3bWTzbh_D1FmwFGblxMvMA1B6P_oEpt8a5aBp0KivYKfRna5oC5VqPb3KJhYeKxj0uhq9ckEHerAYyA3O7BDF3lrov7VodianrWm36NADRjq7DwPAMigMHgNJ_GA4V5TNDSViM43rNPd-AegdCnJW1E_FcA0VpgbYkKTWq9uYnnIU1fNoJz7eLFynszjc0t3yretrrM8O_I8xWOpYshSnOcwQ9WwSI6OmttaZW7AUXVSCR1R2i70JqBhSCnQ6LHwBH6EOJvJhZ23QAc3SVIeH1PnfgtZNiN0DpRP8QUWN24PgutvMkavQz7VD_gDEGg5ww6fii3xStjgL-EBX5KtQdp7-STlqWEfWG8SxYApqtM1JyTq20xKVYExNkYnAZWZhqCZXNNZyIbn8OIZeaFAylRAmz2GfJ3dXYW8q7xldD-qX77oFGio2avf4NS-TU61oEoNrE0w0IJkflgTVq_3X-wWYrehbJ6PIZHL8yqCLoUuxHQ1C-ycYhGPv8XZRH2GP0MQhRN9Qz8Jx8aGaZPR3mqOmlbYWhO04kpU4w_kP2ulgkLjn1WU6sYa9lzrStJ_ESJq4Mo_otuYcQ5ay85EmVTztBW6qL1cEKAmolRP1L0VlITB9WkO4qQBc2V5bsVACtj1N06Ldg4Ql9sOnW6IQinogquS-c2b6dRVoJyw4wZxvxAuyi6kSW77DU6646V6dVUhA4ngvx3G6u99mVZE-Fwhfempc"/>
#          <input name="r" type="hidden" value="7mtdsKdvDD4P2m1C7cMH6GL9hlCoiPiwNDRA0vniRI8-1646855471-0-..."/>
#          <input name="vc" type="hidden" value="be35e3a919b332874d52f42f885f1a83"/>
#          <noscript class="cf-captcha-info" id="cf-captcha-bookmark">
#           <h1 data-translate="turn_on_js" style="color:#bd2426;">
#            Please turn JavaScript on and reload the page.
#           </h1>
#          </noscript>
#          <div class="cookie-warning" data-translate="turn_on_cookies" id="no-cookie-warning" style="display:none">
#           <p data-translate="turn_on_cookies" style="color:#bd2426;">
#            Please enable Cookies and reload the page.
#           </p>
#          </div>
#          <script type="text/javascript">
#           //<![CDATA[
#     var a = function() {try{return !!window.addEventListener} catch(e) {return !1} },
#       b = function(b, c) {a() ? document.addEventListener("DOMContentLoaded", b, c) : document.attachEvent("onreadystatechange", b)};
#       b(function(){
#         var cookiesEnabled=(navigator.cookieEnabled)? true : false;
#         if(!cookiesEnabled){
#           var q = document.getElementById('no-cookie-warning');q.style.display = 'block';
#         }
#       });
#   //]]>
#          </script>
#          <div id="trk_captcha_js" style="background-image:url('/cdn-cgi/images/trace/captcha/nojs/h/transparent.gif?ray=6e965806cd4787d2')">
#          </div>
#         </form>
#         <script type="text/javascript">
#          //<![CDATA[
#     (function(){
#         var isIE = /(MSIE|Trident\/|Edge\/)/i.test(window.navigator.userAgent);
#         var trkjs = isIE ? new Image() : document.createElement('img');
#         trkjs.setAttribute("src", "/cdn-cgi/images/trace/managed/js/transparent.gif?ray=6e965806cd4787d2");
#         trkjs.id = "trk_managed_js";
#         trkjs.setAttribute("alt", "");
#         document.body.appendChild(trkjs);
#         var cpo=document.createElement('script');
#         cpo.type='text/javascript';
#         cpo.src="/cdn-cgi/challenge-platform/h/g/orchestrate/managed/v1?ray=6e965806cd4787d2";
#
#         window._cf_chl_opt.cOgUQuery = location.search === '' && location.href.indexOf('?') !== -1 ? '?' : location.search;
#         window._cf_chl_opt.cOgUHash = location.hash === '' && location.href.indexOf('#') !== -1 ? '#' : location.hash;
#         if (window._cf_chl_opt.cUPMDTk && window.history && window.history.replaceState) {
#           var ogU = location.pathname + window._cf_chl_opt.cOgUQuery + window._cf_chl_opt.cOgUHash;
#           history.replaceState(null, null, "\/?__cf_chl_rt_tk=A2whRMiFHlJ0BneS6V5vJMuIrhMwf0TUbXcfVK0DKd8-1646855471-0-gaNycGzNByU" + window._cf_chl_opt.cOgUHash);
#           cpo.onload = function() {
#             history.replaceState(null, null, ogU);
#           };
#         }
#
#         document.getElementsByTagName('head')[0].appendChild(cpo);
#     }());
#     //]]>
#         </script>
#        </div>
#       </div>
#       <div class="cf-column">
#        <div class="cf-screenshot-container">
#         <span class="cf-no-screenshot">
#         </span>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="cf-section cf-wrapper">
#     <div class="cf-columns two">
#      <div class="cf-column">
#       <h2 data-translate="why_captcha_headline">
#        Why do I have to complete a CAPTCHA?
#       </h2>
#       <p data-translate="why_captcha_detail">
#        Completing the CAPTCHA proves you are a human and gives you temporary access to the web property.
#       </p>
#      </div>
#      <div class="cf-column">
#       <h2 data-translate="resolve_captcha_headline">
#        What can I do to prevent this in the future?
#       </h2>
#       <p data-translate="resolve_captcha_antivirus">
#        If you are on a personal connection, like at home, you can run an anti-virus scan on your device to make sure it is not infected with malware.
#       </p>
#       <p data-translate="resolve_captcha_network">
#        If you are at an office or shared network, you can ask the network administrator to run a scan across the network looking for misconfigured or infected devices.
#       </p>
#      </div>
#     </div>
#    </div>
#    <div class="cf-error-footer cf-wrapper w-240 lg:w-full py-10 sm:py-4 sm:px-8 mx-auto text-center sm:text-left border-solid border-0 border-t border-gray-300">
#     <p class="text-13">
#      <span class="cf-footer-item sm:block sm:mb-1">
#       Cloudflare Ray ID:
#       <strong class="font-semibold">
#        6e965806cd4787d2
#       </strong>
#      </span>
#      <span class="cf-footer-separator sm:hidden">
#       •
#      </span>
#      <span class="cf-footer-item sm:block sm:mb-1">
#       <span>
#        Your IP
#       </span>
#       : 58.187.143.1
#      </span>
#      <span class="cf-footer-separator sm:hidden">
#       •
#      </span>
#      <span class="cf-footer-item sm:block sm:mb-1">
#       <span>
#        Performance &amp; security by
#       </span>
#       <a href="https://www.cloudflare.com/5xx-error-landing" id="brand_link" rel="noopener noreferrer" target="_blank">
#        Cloudflare
#       </a>
#      </span>
#     </p>
#    </div>
#    <!-- /.error-footer -->
#   </div>
#  </div>
#  <script type="text/javascript">
#   window._cf_translation = {};
#  </script>
# </body>

# %%
soup.body.find("div").find_next_sibling()
# Out:
# <script type="text/javascript">
#   window._cf_translation = {};
#
#
# </script>
